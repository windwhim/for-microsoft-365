# %% [markdown]
# #pre

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
import torch
device = torch.device('cuda')
a = torch.randn((10,10,10))
a.to(device)

# %% [markdown]
# #dataset

# %%
# !wget -c http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2023-03-16 05:44:58--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.140.236, 52.217.82.68, 3.5.27.110, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.140.236|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  21.5MB/s    in 15s
#
# 2023-03-16 05:45:13 (16.2 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !wget -c http://images.cocodataset.org/zips/train2017.zip
# Out:
# --2023-03-16 05:45:16--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.104.76, 3.5.3.104, 3.5.29.207, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.104.76|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  80.1MB/s    in 3m 56s
#
# 2023-03-16 05:49:12 (78.2 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]

# %%
# !wget -c http://images.cocodataset.org/zips/val2017.zip
# Out:
# --2023-03-16 05:49:21--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.121.177, 52.217.132.121, 52.216.58.73, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.121.177|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  94.7MB/s    in 8.2s
#
# 2023-03-16 05:49:29 (94.7 MB/s) - ‘val2017.zip’ saved [815585330/815585330]

# %%
# !unzip annotations_trainval2017.zip
# Out:
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
# !unzip train2017.zip

# %%
# !unzip val2017.zip

# %%
# !rm -f train2017.zip

# %%
# !rm -f val2017.zip

# %% [markdown]
# #run

# %%
cd /content/drive/MyDrive/Colab Notebooks/simple_maskrcnn
# Out:
# /content/drive/MyDrive/Colab Notebooks/simple_maskrcnn

# %%
# !dir
# Out:
# alexnet.ipynb	 googlenet.ipynb	   mask_rcnn
# data		 image_augmentation.ipynb  python_packages
# faster_rcnn	 img			   PyTorch-Simple-MaskRCNN
# fcn.ipynb	 import.ipynb		   wget.ipynb
# fine_tune.ipynb  lenet.ipynb		   “欢迎使用\ Colaboratory”的副本

# %%
# !python train.py --use-cuda --epochs 10 --dataset coco --data-dir /content
# Out:
# cuda: True
# available GPU(s): 1
# 0: {'name': 'Tesla T4', 'capability': [7, 5], 'total_momory': 14.75, 'sm_count': 40}
#
# device: cuda
# loading annotations into memory...
# Done (t=18.04s)
# creating index...
# index created!
# ==============len(data_train)========= 117266
# ===========d_train========== 117266
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Namespace(use_cuda=True, dataset='coco', data_dir='/content', ckpt_path='./maskrcnn_coco.pth', results='./maskrcnn_results.pth', seed=3, lr_steps=[6, 7], lr=0.00125, momentum=0.9, weight_decay=0.0001, epochs=10, iters=10, print_freq=100, warmup_iters=117266)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# already trained: 0 epochs; to 10 epochs
#
# epoch: 1
# lr_epoch: 0.00125, factor: 1.00000
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 0	 0.691	0.162	0.058	0.033	0.301
# iter: 333.9, total: 314.4, model: 213.3, backward: 25.6
# iter: 155.6, total: 140.8, model: 122.9
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.07s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.07s).
# accumulate: 0.2s
# training: 3.3 s, evaluation: 4.6 s
# {'bbox AP': 24.2, 'mask AP': 24.1}
#
# epoch: 2
# lr_epoch: 0.00125, factor: 1.00000
# iter: 182.8, total: 169.2, model: 70.6, backward: 12.9
# iter: 161.1, total: 146.2, model: 125.8
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 1.8 s, evaluation: 3.3 s
# {'bbox AP': 18.3, 'mask AP': 17.1}
#
# epoch: 3
# lr_epoch: 0.00125, factor: 1.00000
# iter: 200.0, total: 176.3, model: 77.9, backward: 26.1
# iter: 222.8, total: 203.0, model: 182.3
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.11s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.10s).
# accumulate: 0.3s
# training: 2.0 s, evaluation: 6.1 s
# {'bbox AP': 19.5, 'mask AP': 17.4}
#
# epoch: 4
# lr_epoch: 0.00125, factor: 1.00000
# 351800	 0.443	0.132	0.036	0.036	0.208
# iter: 189.1, total: 175.9, model: 69.5, backward: 14.0
# iter: 158.0, total: 143.5, model: 123.1
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.11s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.09s).
# accumulate: 0.3s
# training: 1.9 s, evaluation: 6.1 s
# {'bbox AP': 15.4, 'mask AP': 13.9}
#
# epoch: 5
# lr_epoch: 0.00125, factor: 1.00000
# iter: 192.9, total: 171.8, model: 72.6, backward: 17.4
# iter: 166.0, total: 148.3, model: 130.4
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 1.9 s, evaluation: 3.4 s
# {'bbox AP': 16.2, 'mask AP': 13.4}
#
# epoch: 6
# lr_epoch: 0.00125, factor: 1.00000
# iter: 193.6, total: 177.1, model: 71.7, backward: 16.3
# iter: 194.5, total: 176.5, model: 153.5
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.07s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 1.9 s, evaluation: 3.7 s
# {'bbox AP': 16.6, 'mask AP': 13.6}
#
# epoch: 7
# lr_epoch: 0.00013, factor: 0.10000
# 703600	 0.117	0.132	0.036	0.008	0.150
# iter: 203.7, total: 173.4, model: 79.6, backward: 23.1
# iter: 195.6, total: 174.3, model: 153.6
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 2.0 s, evaluation: 3.7 s
# {'bbox AP': 17.0, 'mask AP': 13.8}
#
# epoch: 8
# lr_epoch: 0.00001, factor: 0.01000
# iter: 188.1, total: 174.1, model: 68.6, backward: 12.1
# iter: 159.4, total: 145.0, model: 123.0
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 1.9 s, evaluation: 3.3 s
# {'bbox AP': 17.0, 'mask AP': 13.8}
#
# epoch: 9
# lr_epoch: 0.00001, factor: 0.01000
# iter: 195.1, total: 175.4, model: 71.3, backward: 17.2
# iter: 188.3, total: 168.8, model: 145.6
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# accumulate: 0.2s
# training: 2.0 s, evaluation: 3.6 s
# {'bbox AP': 17.0, 'mask AP': 13.8}
#
# epoch: 10
# lr_epoch: 0.00001, factor: 0.01000
# 1055400	 0.179	0.087	0.185	0.113	0.230
# iter: 193.4, total: 179.5, model: 69.3, backward: 12.3
# iter: 164.1, total: 149.2, model: 126.6
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.10s).
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.10s).
# accumulate: 0.3s
# training: 1.9 s, evaluation: 6.4 s
# {'bbox AP': 16.8, 'mask AP': 13.6}
#
# total time of this training: 79.1 s
# already trained: 10 epochs
